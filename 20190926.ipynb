# %% [markdown]
# ## R for Data Science_20190926
#
# <br>
#
# 깃허브에서 하던 작업 다른 PC에서 작업하고 싶으면 <br>
# Clone or download 클릭하고 <br>
# git clone https://github.com/ssujinK/tmp.git <br>
# git add . <- 파일명 넣기 <br>
# git commit -m "readme update" <br>
# git push <br><br>
#
#
# < JUPYTER NOTEBOOK WITH R > <br>
# read.table(".")  <- 파일 리딩이 너무 느림 <br>
# fread in data.table library <br>
# readr in tidyverse library  <br>
# -> 빠르고 효율적이고 문법도 쉬움 <br><br>
#
#
# < R for Data Science > <br>
# Hadley Wickham - https://r4ds.had.co.nz/ <br>
# [R for Data Science]("https://r4ds.had.co.nz/") - 교재 <br><br>
#
#
# #### < 3.3. Aesthetic mappings > <br>
# <https://r4ds.had.co.nz/data-visualisation.html#aesthetic-mappings>

# %%
library(tidyverse)

ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, color = class, size = cyl))
# color, size, alpha, shape 옵션 추가/변경 가능
# Out:
# plot without title

# %% [markdown]
# #### < 3.5. Facets > <br>

# %%
# for univariate
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) + 
  facet_wrap(~ class, nrow = 2)
# Out:
# plot without title

# %%
# bivariate
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) + 
  facet_grid(drv ~ cyl)
# Out:
# plot without title

# %%
# bivariate
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) + 
  geom_point() + 
  facet_grid(drv ~ cyl)
# Out:
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) + 
  geom_point() + 
  geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = diamonds) + 
  geom_bar(mapping = aes(x = cut))
# Out:
# plot without title

# %% [markdown]
# ####  < Theme >

# %%
# for univariate
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) + 
  facet_wrap(~ class, nrow = 2) + theme_bw() +
  theme(axis.line = element_line(size = 0.8, colour = "black"),
        panel.grid.minor = element_blank(),
        panel.border = element_blank(),
        text = element_text(size = 25)
        )
# theme_bw() - theme 적용
# 이걸 기반으로 수정하면서 사용
# Out:
# plot without title

# %%
bar <- ggplot(data = diamonds) + 
  geom_bar(
    mapping = aes(x = cut, fill = cut), 
    show.legend = FALSE,
    width = 1
  ) + 
  theme(aspect.ratio = 1) +
  labs(x = NULL, y = NULL)

bar + coord_flip()
bar + coord_polar()
# Out:
# plot without title
# plot without title

# %% [markdown]
# #### < Filter >

# %%
#install.packages("nycflights13")
#library(nycflights13)

head(flights)
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# ...

# %%
head(filter(flights, month == 1, day == 1))
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# ...

# %%
head(filter(flights, month == 11 | month == 12))
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 11    1     5      2359             6       352       345
# 2 2013 11    1    35      2250           105       123      2356
# 3 2013 11    1   455       500            -5       641       651
# 4 2013 11    1   539       545            -6       856       827
# 5 2013 11    1   542       545            -3       831       855
# 6 2013 11    1   549       600           -11       912       923
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1   7       B6       745   N568JB  JFK    PSE  205      1617     23   59
# 2  87       B6      1816   N353JB  JFK    SYR   36       209     22   50
# 3 -10       US      1895   N192UW  EWR    CLT   88       529      5    0
# 4  29       UA      1714   N38727  LGA    IAH  229      1416      5   45
# 5 -24       AA      2243   N5CLAA  JFK    MIA  147      1089      5   45
# ...

# %%
head(filter(flights, month %in% c(11,12)))
# filter(flights, month == 11 | month == 12)와 동일한 결과 출력
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 11    1     5      2359             6       352       345
# 2 2013 11    1    35      2250           105       123      2356
# 3 2013 11    1   455       500            -5       641       651
# 4 2013 11    1   539       545            -6       856       827
# 5 2013 11    1   542       545            -3       831       855
# 6 2013 11    1   549       600           -11       912       923
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1   7       B6       745   N568JB  JFK    PSE  205      1617     23   59
# 2  87       B6      1816   N353JB  JFK    SYR   36       209     22   50
# 3 -10       US      1895   N192UW  EWR    CLT   88       529      5    0
# 4  29       UA      1714   N38727  LGA    IAH  229      1416      5   45
# 5 -24       AA      2243   N5CLAA  JFK    MIA  147      1089      5   45
# ...

# %% [markdown]
# #### < Arrange >

# %%
head(arrange(flights, dep_delay))
# defalt는 오름차순
# desc()는 내림차순
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 12     7  2040     2123           -43         40     2352
# 2 2013  2     3  2022     2055           -33       2240     2338
# 3 2013 11    10  1408     1440           -32       1549     1559
# 4 2013  1    11  1900     1930           -30       2233     2243
# 5 2013  1    29  1703     1730           -27       1947     1957
# 6 2013  8     9   729      755           -26       1002      955
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  48       B6        97   N592JB  JFK    DEN  265      1626     21   23
# 2 -58       DL      1715   N612DL  LGA    MSY  162      1183     20   55
# 3 -10       EV      5713   N825AS  LGA    IAD   52       229     14   40
# 4 -10       DL      1435   N934DL  LGA    TPA  139      1010     19   30
# 5 -10       F9       837   N208FR  LGA    DEN  250      1620     17   30
# ...

# %% [markdown]
# #### < Select >

# %%
head(select(flights, year, month, day))
# Out:
#   year month day
# 1 2013 1     1
# 2 2013 1     1
# 3 2013 1     1
# 4 2013 1     1
# 5 2013 1     1
# 6 2013 1     1

# %% [markdown]
# #### < Mutate >

# %%
flights_sml <- select(flights, 
  year:day, 
  ends_with("delay"), 
  distance, 
  air_time
)
head(mutate(flights_sml,
  gain = dep_delay - arr_delay,
  speed = distance / air_time * 60
))
# Out:
#   year month day dep_delay arr_delay distance air_time gain speed
# 1 2013 1     1    2         11       1400     227       -9  370.0441
# 2 2013 1     1    4         20       1416     227      -16  374.2731
# 3 2013 1     1    2         33       1089     160      -31  408.3750
# 4 2013 1     1   -1        -18       1576     183       17  516.7213
# 5 2013 1     1   -6        -25        762     116       19  394.1379
# 6 2013 1     1   -4         12        719     150      -16  287.6000

# %% [markdown]
# #### < Summarize >

# %%
by_day <- group_by(flights, year, month, day)
head(summarise(by_day, delay = mean(dep_delay, na.rm = TRUE)))
# Out:
#   year month day delay
# 1 2013 1     1   11.548926
# 2 2013 1     2   13.858824
# 3 2013 1     3   10.987832
# 4 2013 1     4    8.951595
# 5 2013 1     5    5.732218
# 6 2013 1     6    7.148014

# %% [markdown]
# #### < Pipe Operators %>% >
#
# x %>% f(y) == f(x,y) <br>
# x %>% f(y) %>% g(z) == g(f(x,y)) <br>
# 첫번째 인자로 들어감

# %%
by_dest <- group_by(flights, dest)
delay <- summarise(by_dest,
  count = n(),
  dist = mean(distance, na.rm = TRUE),
  delay = mean(arr_delay, na.rm = TRUE)
)
delay <- filter(delay, count > 20, dest != "HNL")

head(delay)
# Out:
#   dest count dist      delay
# 1 ABQ    254 1826.0000  4.381890
# 2 ACK    265  199.0000  4.852273
# 3 ALB    439  143.0000 14.397129
# 4 ATL  17215  757.1082 11.300113
# 5 AUS   2439 1514.2530  6.019909
# 6 AVL    275  583.5818  8.003831

# %%
delays <- flights %>% 
  group_by(dest) %>% 
  summarise(
    count = n(),
    dist = mean(distance, na.rm = TRUE),
    delay = mean(arr_delay, na.rm = TRUE)
  ) %>% 
  filter(count > 20, dest != "HNL")

head(delay)

# 위 코드와 동일한 결과 (pipe operator 사용)
# Out:
#   dest count dist      delay
# 1 ABQ    254 1826.0000  4.381890
# 2 ACK    265  199.0000  4.852273
# 3 ALB    439  143.0000 14.397129
# 4 ATL  17215  757.1082 11.300113
# 5 AUS   2439 1514.2530  6.019909
# 6 AVL    275  583.5818  8.003831

# %%
flights %>%
group_by(dest) %>%
summarize(count = n(),
         dist = mean(distance, na.rm = TRUE)) %>%
ggplot(aes(x = dest, y = count))+
geom_bar(stat = "identity")
# Out:
# plot without title

# %% [markdown]
# #### < Gather >

# %%
table4a
# Out:
#   country     1999   2000
# 1 Afghanistan    745   2666
# 2 Brazil       37737  80488
# 3 China       212258 213766

# %%
table4a %>%
    gather(`1999`, `2000`, key = "year", vlaue = 'cases')
# Out:
# Unknown column `cases` Traceback:
#
# 1. table4a %>% gather(`1999`, `2000`, key = "year", vlaue = "cases")
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)
# 9. gather(., `1999`, `2000`, key = "year", vlaue = "cases")
# 10. gather.data.frame(., `1999`, `2000`, key = "year", vlaue = "cases")
# 11. unname(tidyselect::vars_select(names(data), !!!quos))
# 12. tidyselect::vars_select(names(data), !!!quos)
# 13. vars_select_eval(.vars, quos)
# 14. map_if(ind_list, is_character, match_strings, names = TRUE)
# 15. map(.x[sel], .f, ...)
# 16. .f(.x[[i]], ...)
# 17. bad_unknown_vars(vars, unknown)
# 18. abort(glue("Unknown { thing } { fmt_args(unknown) } "))

# %%
table2 %>%
    spread(key = type, value=count)
# gather <-> spread 반대 기능
# Out:
#   country     year cases  population
# 1 Afghanistan 1999    745   19987071
# 2 Afghanistan 2000   2666   20595360
# 3 Brazil      1999  37737  172006362
# 4 Brazil      2000  80488  174504898
# 5 China       1999 212258 1272915272
# 6 China       2000 213766 1280428583
